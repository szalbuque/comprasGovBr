# %% [markdown]
# https://www.transparencia.gov.br/download-de-dados/compras
# Planilha compras (Janeiro 2021)

# %% [markdown]
# O objetivo deste notebook é manipular a tabela com dados de compras dos órgãos do governo federal, a fim de conhecer melhor seu conteúdo, para posteriores pesquisas.

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/dados/202101_Compras.csv',sep=';',encoding= 'unicode_escape')
df.head()
# Out:
#    Número do Contrato                                             Objeto  \
# 0              182020  Objeto: Aquisição de fitas regraváveis e de li...
# 1              212020                 Objeto: Aquisição de 20 notebooks.
# 2              492020  Objeto: Contratação de serviços continuados de...
# 3             1482020  Objeto: Aquisição de órteses,próteses e materi...
# 4              392020  Objeto: Contratação de empresa especializada n...
#
#                                     Fundamento Legal  \
# 0             Fundamento Legal: Lei nº 8.666 de 1993
# 1  Fundamento Legal: Decret7892/2013 e Decreto 10...
# 2                      Fundamento Legal: Lei 8666/93
# 3                     Fundamento Legal: Lei 13303/16
# 4                    Fundamento Legal: Lei 8666/1993
#
#             Modalidade Compra Situação Contrato  Código Órgão Superior  \
# 0                      Pregão         Publicado                  25000
# ...

# %%
# Cria um dataframe df_hospit contendo somente as linhas de df que contém a string 'HOSPIT' na coluna 'Nome UG' E a string 'Aquisição' na coluna 'Objeto'
df_hospit = df.loc[df['Nome UG'].str.contains('HOSPIT')  & df['Objeto'].str.contains('Aquisição')]

df_hospit
# Out:
#     Número do Contrato                                             Objeto  \
# 3              1482020  Objeto: Aquisição de órteses,próteses e materi...
# 34              652020  Objeto: Aquisição de equipamentos para os micr...
# 40             1502020  Objeto: Aquisição de teste rápido Covid 19 - a...
# 83             1472020  Objeto: Aquisição de órteses,próteses e materi...
#
#                    Fundamento Legal           Modalidade Compra  \
# 3    Fundamento Legal: Lei 13303/16  Pregão - Registro de Preço
# 34  Fundamento Legal: Lei 13.303/16  Pregão - Registro de Preço
# 40   Fundamento Legal: Lei 13303/16       Dispensa de Licitação
# 83   Fundamento Legal: Lei 13303/16  Pregão - Registro de Preço
#
#    Situação Contrato  Código Órgão Superior     Nome Órgão Superior  \
# 3          Publicado                  26000  Ministério da Educação
# 34         Publicado                  26000  Ministério da Educação
# ...

# %% [markdown]
# Cria o dataframe df_nomeorgsup usando a coluna do nome do órgão superior como índice

# %%
df_nomeorgsup = df.set_index('Nome Órgão Superior')
df_nomeorgsup.head()
# Out:
#                                                Número do Contrato  \
# Nome Órgão Superior
# Ministério da Economia                                     182020
# Ministério do Desenvolvimento Regional                     212020
# Ministério da Educação                                     492020
# Ministério da Educação                                    1482020
# Ministério da Agricultura, Pecuária e Abastec              392020
#
#                                                                                           Objeto  \
# Nome Órgão Superior
# Ministério da Economia                         Objeto: Aquisição de fitas regraváveis e de li...
# Ministério do Desenvolvimento Regional                        Objeto: Aquisição de 20 notebooks.
# Ministério da Educação                         Objeto: Contratação de serviços continuados de...
# Ministério da Educação                         Objeto: Aquisição de órteses,próteses e materi...
# ...

# %%
# seleciona somente as linhas em que o nome do órgão superior é 'Ministério da Educação'
df3 = df_nomeorgsup.loc['Ministério da Educação']
df3.head()
# Out:
#                         Número do Contrato  \
# Nome Órgão Superior
# Ministério da Educação              492020
# Ministério da Educação             1482020
# Ministério da Educação              202020
# Ministério da Educação              232020
# Ministério da Educação               22020
#
#                                                                    Objeto  \
# Nome Órgão Superior
# Ministério da Educação  Objeto: Contratação de serviços continuados de...
# Ministério da Educação  Objeto: Aquisição de órteses,próteses e materi...
# Ministério da Educação  Objeto: Contratação de serviços continuados de...
# Ministério da Educação  Objeto: Contratação da Fundação de Empreendime...
# Ministério da Educação  Objeto: Contratação de serviço comum de engenh...
#
#                                                          Fundamento Legal  \
# Nome Órgão Superior
# Ministério da Educação                      Fundamento Legal: Lei 8666/93
# ...

# %% [markdown]
# Cria o dataframe df_nomeorg usando a coluna 'Nome Órgão' como índice

# %%
df_nomeorg = df.set_index('Nome Órgão')
df_nomeorg.head()
# Out:
#                                                Número do Contrato  \
# Nome Órgão
# Superintendência Nacional de Previdência Comp              182020
# Superintendência do Desenvolvimento da Amazôn              212020
# Fundação Universidade do Maranhão                          492020
# Empresa Brasileira de Serviços Hospitalares               1482020
# Ministério da Agricultura, Pecuária e Abastec              392020
#
#                                                                                           Objeto  \
# Nome Órgão
# Superintendência Nacional de Previdência Comp  Objeto: Aquisição de fitas regraváveis e de li...
# Superintendência do Desenvolvimento da Amazôn                 Objeto: Aquisição de 20 notebooks.
# Fundação Universidade do Maranhão              Objeto: Contratação de serviços continuados de...
# Empresa Brasileira de Serviços Hospitalares    Objeto: Aquisição de órteses,próteses e materi...
# ...

# %%
# seleciona somente as linhas em que o nome do órgão possui a palavra 'Empresa Brasileira de Serviços Hospitalares'
df_hospit = df_nomeorg.loc['Empresa Brasileira de Serviços Hospitalares']
df_hospit.head()
# Out:
#                                              Número do Contrato  \
# Nome Órgão
# Empresa Brasileira de Serviços Hospitalares             1482020
# Empresa Brasileira de Serviços Hospitalares              652020
# Empresa Brasileira de Serviços Hospitalares              162020
# Empresa Brasileira de Serviços Hospitalares             1502020
# Empresa Brasileira de Serviços Hospitalares             1882020
#
#                                                                                         Objeto  \
# Nome Órgão
# Empresa Brasileira de Serviços Hospitalares  Objeto: Aquisição de órteses,próteses e materi...
# Empresa Brasileira de Serviços Hospitalares  Objeto: Aquisição de equipamentos para os micr...
# Empresa Brasileira de Serviços Hospitalares  Objeto: Serviços gerais de manutenção preventi...
# Empresa Brasileira de Serviços Hospitalares  Objeto: Aquisição de teste rápido Covid 19 - a...
# ...

# %%
# Seleciona somente as linhas em que a coluna 'Nome UG' contém a string 'HOSPIT'
df_hospit = df_nomeorg.loc[df_nomeorg['Nome UG'].str.contains('HOSPIT')]
df_hospit.head()
